# %%
import requests
from bs4 import BeautifulSoup
import urllib
country = '미국'
language = '공식언어'
url = 'http://www.google.co.kr/search?ei=aKSnWuOIOIrJ0ASqgpioCg&q='+country+' '+language

# %%
url
# Out:
# 'https://www.google.co.kr/search?ei=aKSnWuOIOIrJ0ASqgpioCg&q=미국 공식언어'

# %%
adjust_country = urllib.parse.quote(country)   
adjust_language = urllib.parse.quote(language)

# %%
url = 'http://www.google.co.kr/search?ei=aKSnWuOIOIrJ0ASqgpioCg&q='+adjust_country+' '+adjust_language    
url
# Out:
# 'http://www.google.co.kr/search?ei=aKSnWuOIOIrJ0ASqgpioCg&q=%EB%AF%B8%EA%B5%AD %EA%B3%B5%EC%8B%9D%EC%96%B8%EC%96%B4'

# %%
response = requests.get(url)

# %%
dom = BeautifulSoup(response.content, "html.parser")

# %%
dom.select("")
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
//*[@id="uid_gqSnWsupIsPo0AS9_YCgDA_0"]/div/div
