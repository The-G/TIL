# %% [markdown]
# # ViolinPlot

# %%
import seaborn as sns

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f9315ad195e1> in <module>()
# ----> 1 plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
#
# NameError: name 'plt' is not defined

# %%
sns.set_style("whitegrid")
tips = sns.load_dataset("tips")
ax = sns.violinplot(x=tips["total_bill"])

# %%
tips["total_bill"].head(5)

# %% [markdown]
# ### Draw a single horizontal violinplot

# %%
plt.show()

# %%
tips[["day","total_bill"]].head()
# Out:
#    day  total_bill
# 0  Sun       16.99
# 1  Sun       10.34
# 2  Sun       21.01
# 3  Sun       23.68
# 4  Sun       24.59

# %% [markdown]
# ### Draw a vertical violinplot grouped by a categorical variable

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.violinplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
tips[["day","total_bill","smoker"]].head()
# Out:
#    day  total_bill smoker
# 0  Sun       16.99     No
# 1  Sun       10.34     No
# 2  Sun       21.01     No
# 3  Sun       23.68     No
# 4  Sun       24.59     No

# %% [markdown]
# ### Draw a violinplot with nested grouping by two categorical variabels

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.violinplot(x="day", y="total_bill", hue="smoker",
                     data=tips, palette="muted", split=False)
plt.show()

# %% [markdown]
# ### Draw split violins to compare the across the hue variable

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.violinplot(x="day", y="total_bill", hue="smoker",
                    data=tips, palette="muted", split=True)
plt.show()

# %%
tips[["time","tip"]].head()
# Out:
#      time   tip
# 0  Dinner  1.01
# 1  Dinner  1.66
# 2  Dinner  3.50
# 3  Dinner  3.31
# 4  Dinner  3.61

# %% [markdown]
# ### Control violin order by passing an explicit order

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.violinplot(x="time", y="tip", data=tips,
                     order=["Dinner", "Lunch"])
plt.show()

# %%
tips[["day","total_bill","sex"]].head()
# Out:
#    day  total_bill     sex
# 0  Sun       16.99  Female
# 1  Sun       10.34    Male
# 2  Sun       21.01    Male
# 3  Sun       23.68    Male
# 4  Sun       24.59  Female

# %% [markdown]
# ### Scale the violin width by the number of observations in each bin

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.violinplot(x="day", y="total_bill", hue="sex",
                     data=tips, palette="Set2", split=True,
                     scale="count")
plt.show()

# %% [markdown]
# ### Draw the quartiles as horizontal lines instead of a mini-box

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.violinplot(x="day", y="total_bill", hue="sex",
                     data=tips, palette="Set2", split=True,
                     scale="count", inner="quartile")
plt.show()

# %% [markdown]
# ### Show each observation with a stick inside the violin

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.violinplot(x="day", y="total_bill", hue="sex",
                    data=tips, palette="Set2", split=True,
                    scale="count", inner="stick", scale_hue=True)
plt.show()

# %% [markdown]
# ### Scale the density relative to the counts across all bins

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.violinplot(x="day", y="total_bill", hue="sex",
                    data=tips, palette="Set2", split=True,
                    scale="count", inner="stick", scale_hue=False)
plt.show()

# %% [markdown]
# ### Use a narrow bandwidth to reduce the amount of smoothing

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.violinplot(x="day", y="total_bill", hue="sex",
                    data=tips, palette="Set2", split=True,
                    scale="count", inner="stick",
                    scale_hue=False, bw=.2)
plt.show()

# %%
planets = sns.load_dataset("planets")

# %%
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# ### Draw horizontal violins

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.violinplot(x="orbital_period", y="method",
                    data=planets[planets.orbital_period < 1000],
                    scale="width", palette="Set3")
plt.show()

# %% [markdown]
# ### Don't let density extend past extreme values in the data

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.violinplot(x="orbital_period", y="method",
                    data=planets[planets.orbital_period < 1000],
                    cut=0, scale="width", palette="Set3")
plt.show()

# %% [markdown]
# ### Use hue without changing violin position or width

# %%
tips["day"].unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
tips["weekend"] = tips["day"].isin(["Sat", "Sun"])
ax = sns.violinplot(x="day", y="total_bill", hue="weekend",
                    data=tips, dodge=False)
plt.show()

# %% [markdown]
# ### Use factorplot() to combine a violinplot() and a FacetGrid. This allows grouping within additional categorical variables. Using factorplot() is safer than using FacetGrid directly, as it ensures synchronization of variable order across facets:

# %%
g = sns.factorplot(x="sex", y="total_bill",
                   hue="smoker", col="time",
                   data=tips, kind="violin", split=True,
                   size=8, aspect=0.7);
plt.show()

# %% [markdown]
# # BoxPlot

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
sns.set_style("whitegrid")
ax = sns.boxplot(x=tips["total_bill"])
plt.show()

# %%
tips[["day","total_bill"]].head()
# Out:
#    day  total_bill
# 0  Sun       16.99
# 1  Sun       10.34
# 2  Sun       21.01
# 3  Sun       23.68
# 4  Sun       24.59

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.boxplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
tips[["day","total_bill","smoker"]].head()
# Out:
#    day  total_bill smoker
# 0  Sun       16.99     No
# 1  Sun       10.34     No
# 2  Sun       21.01     No
# 3  Sun       23.68     No
# 4  Sun       24.59     No

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.boxplot(x="day", y="total_bill", hue="smoker",
                 data=tips, palette="Set3")
plt.show()

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.boxplot(x="day", y="total_bill", hue="time",
                 data=tips, linewidth=2.5)
plt.show()

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.boxplot(x="time", y="tip", data=tips,
                 order=["Dinner", "Lunch"])
plt.show()

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
iris = sns.load_dataset("iris")
ax = sns.boxplot(data=iris, orient="h", palette="Set2")
plt.show()

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
tips["weekend"] = tips["day"].isin(["Sat", "Sun"])
ax = sns.boxplot(x="day", y="total_bill", hue="weekend",
                 data=tips, dodge=False)
plt.show()

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.boxplot(x="day", y="total_bill", data=tips)
ax = sns.swarmplot(x="day", y="total_bill", data=tips, color=".25")
plt.show()

# %%
g = sns.factorplot(x="sex", y="total_bill",
                   hue="smoker", col="time",
                   data=tips, kind="box",
                   size=8, aspect=.7);
plt.show()

# %%
import seaborn as sns; sns.set(color_codes=True)
import matplotlib.pyplot as plt
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
gammas = sns.load_dataset("gammas")
ax = sns.tsplot(time="timepoint", value="BOLD signal",
                unit="subject", condition="ROI",
                data=gammas)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
plt.show()

# %%
gammas.head()
# Out:
#    timepoint  ROI  subject  BOLD signal
# 0        0.0  IPS        0     0.513433
# 1        0.0  IPS        1    -0.414368
# 2        0.0  IPS        2     0.214695
# 3        0.0  IPS        3     0.814809
# 4        0.0  IPS        4    -0.894992

# %%
import numpy as np
x = np.linspace(0, 15, 31)
data = np.sin(x) + np.random.rand(10, 31) + np.random.randn(10, 1)
data
# Out:
# array([[-0.9233099 , -0.15004746, -0.05099377,  0.35365239,  0.16572115,
#         -0.37442022, -0.66043277,  0.40565912,  0.71365551, -0.03024247,
#         -0.05429501],
#        [-1.10874795, -0.51951217, -0.55776362, -0.54186057, -0.62648812,
#         -0.28505088, -0.8429406 , -1.59178546, -2.03953663, -1.58725328,
#         -1.96458318, -2.02339664, -0.90551674, -0.77464207, -0.51234892,
#          0.20617881, -0.53890846, -0.63621758, -0.88505205, -0.6805835 ,
#         -1.23495262, -2.14765488, -2.07108278, -1.9445902 , -1.19413445,
#         -1.0678564 , -0.44557439, -0.32134835, -0.44277325,  0.23164404,
#         -0.57022863],
#        [ 0.98156072,  2.40337356,  2.60007885,  2.63092363,  2.69795262,
#          1.62967911,  1.48709574,  1.03782614,  0.28347023,  0.93202428,
#          0.06923209,  1.15151257,  1.37152171,  1.51191775,  1.86771762,
#          2.30344788,  2.03036279,  2.6801903 ,  2.01798275,  0.92949043,
#          0.88123455,  0.16054037,  0.38531826,  0.83968286,  1.32890408,
#          1.54396909,  1.9344428 ,  2.3841998 ,  2.4212239 ,  2.03122653,
#          2.54772424],
#        [ 0.20527688,  1.02464569,  0.61743192,  1.266564  ,  0.8469678 ,
#          0.7683328 ,  0.31619123, -0.31823256, -1.06124955, -0.90657496,
#         -0.81067592, -0.12149664,  0.18854424,  0.1880619 ,  0.35254477,
#          0.67251326,  1.50945078,  0.87660606,  0.7300779 , -0.13533036,
#         -0.60142063, -0.76040063, -0.62384595, -0.36482294, -0.29020669,
#         -0.26287024,  0.99212624,  0.73114251,  0.81246145,  1.24931879,
#          1.02714518],
#        [ 1.02588504,  1.25649141,  1.15814616,  2.17050705,  1.97830222,
#          1.60330531,  0.88050528,  0.70154561, -0.06371609, -0.25018869,
#         -0.04524416,  0.35443881,  0.72425303,  0.83170819,  1.12299737,
#          1.87395789,  1.82123771,  1.2025323 ,  1.13023514,  0.84500028,
#          0.06047543, -0.4474896 , -0.59859025, -0.35568919, -0.2814757 ,
#          0.77307591,  0.71762594,  1.68287524,  2.09923625,  1.56911038,
#          1.00436195]])

# %%
import pandas as pd

# %%
pd.DataFrame(x)
# Out:
#        0
# 0    0.0
# 1    0.5
# 2    1.0
# 3    1.5
# 4    2.0
# 5    2.5
# 6    3.0
# 7    3.5
# 8    4.0
# 9    4.5
# 10   5.0
# 11   5.5
# 12   6.0
# 13   6.5
# 14   7.0
# 15   7.5
# 16   8.0
# 17   8.5
# 18   9.0
# 19   9.5
# 20  10.0
# 21  10.5
# 22  11.0
# 23  11.5
# 24  12.0
# 25  12.5
# 26  13.0
# 27  13.5
# 28  14.0
# 29  14.5
# 30  15.0

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
ax = sns.tsplot(data=data, err_style="ci_bars", color="g")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
